# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 80)

# %%
house = pd.read_csv(r'C:\Users\user\Desktop\data-science-journey\jupyter notebooks files\house-prices-advanced-regression-techniques\train.csv')
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
house.shape
# Out:
# (1460, 81)

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# # columns of importance that i will be working with
#
# #### salesprice   - Final house price (TARGET)
# #### OverallQual  - Overall material & finish quality (1–10)
# #### GrLivArea  - Above-ground living area
# #### YearBuilt   - Year house was built
# #### TotalBsmtSF  - Basement size
# #### GarageCars   - Number of cars garage can hold
# #### Neighborhood  - Physical location

# %%
# MISSING VALUES

missing = house.isnull().sum()

missing[missing > 0].sort_values(ascending = False).head(10)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# dtype: int64

# %%
house.isnull().sum()[house.isnull().sum() > 0].sort_values(ascending = False).head(10)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# dtype: int64

# %%
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# look at sales price column

house['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
house['SalePrice'].median()
# Out:
# 163000.0

# %%
house['SalePrice'].isnull().sum()
# Out:
# np.int64(0)

# %%
# want to visualize the sales price column before any cleaning

plt.hist(house['SalePrice'], bins = 30)
plt.xlabel('SalePrice')
plt.ylabel('frequency')
plt.title('price distribution (raw data)')
plt.show()

# %%
# boxplot of the same sale price column

plt.boxplot(house['SalePrice'])
plt.xlabel('Sales Price')
plt.title('sales price distribution')
plt.show()

# %%
# look at the relation between size and price

plt.scatter(house['SalePrice'], house['GrLivArea'])
plt.xlabel('living area by sq(ft)')
plt.ylabel('sales price')
plt.title('living area vs sales price')
plt.show()

# %%
# look at the missing values again to get more insights

missing = house.isnull().sum()

missing[missing > 0].sort_values(ascending = False).head(10)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# dtype: int64

# %%
# the first four column has high missing values hence will be dropped

house = house.drop(columns = ['PoolQC', 'MiscFeature', 'Alley', 'Fence'])

# %%
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
# handle missing numeric data

house.select_dtypes(include = 'number').isnull().sum().sort_values(ascending = False)
# Out:
# LotFrontage      259
# GarageYrBlt       81
# MasVnrArea         8
# LotArea            0
# MSSubClass         0
# Id                 0
# OverallCond        0
# OverallQual        0
# YearRemodAdd       0
# YearBuilt          0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# BsmtFinSF1         0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# 1stFlrSF           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
# LotFrontage      259
# GarageYrBlt       81
# MasVnrArea         8

# this are the columns that have numeric missing numbers
# fill them using median as mean will not be appropriate because of outliers

house['LotFrontage'] = house['LotFrontage'].fillna(house['LotFrontage'].median())
house['GarageYrBlt'] = house['GarageYrBlt'].fillna(house['GarageYrBlt'].median())
house['MasVnrArea'] = house['MasVnrArea'].fillna(house['MasVnrArea'].median())

# %%
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
# drop the MasVnrArea column because of many missing values 
house = house.drop(columns = 'MasVnrArea')
house
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
house.select_dtypes(include = 'number').isnull().sum().sort_values(ascending = False)
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
# HANDLE CATEGORICAL MISSING VALUES USING MODE

house.select_dtypes(include = 'object').isnull().sum().sort_values(ascending = False).head(10)
# Out:
# MasVnrType      872
# FireplaceQu     690
# GarageQual       81
# GarageType       81
# GarageFinish     81
# GarageCond       81
# BsmtFinType2     38
# BsmtExposure     38
# BsmtCond         37
# BsmtQual         37
# dtype: int64

# %%
# fill with most frequent values

for col in house.select_dtypes(include = 'object'):
    house[col] = house[col].fillna(house[col].mode()[0])

# %%
# check for missing value and there is none
house.select_dtypes(include = 'object').isnull().sum().sort_values(ascending = False).head(10)
# Out:
# MSZoning        0
# Street          0
# LotShape        0
# LandContour     0
# Utilities       0
# LotConfig       0
# LandSlope       0
# Neighborhood    0
# Condition1      0
# Condition2      0
# dtype: int64

# %%
house.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 76, dtype: int64

# %%
# sales price skewed
# mean > median, automatically it is skewed

house['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
house['SalePrice'].median()
# Out:
# 163000.0

# %%
# histogram representation of the sale price column

plt.hist(house['SalePrice'], bins = 30)
plt.xlabel('sale price')
plt.ylabel('frequency')
plt.title('price distribution (original data)')
plt.show()

# %%
# FIX SKEW USING LOG TRANSFORM
house['SalePrice_log'] = np.log1p(house['SalePrice'])

# %%
# histogram plot for the log transform

plt.hist(house['SalePrice_log'], bins = 30)
plt.xlabel('log sale price')
plt.ylabel('frequency')
plt.title('price distribution (original data)')
plt.show()

# %%
# living area vs price

plt.scatter(house['GrLivArea'], house['SalePrice'], alpha = 0.5)
plt.ylabel('Living Area')
plt.xlabel('Sale Price')
plt.title('living area vs price')
plt.show()

# %%
# living area vs log sale price

plt.scatter(house['GrLivArea'],house['SalePrice_log'], alpha = 0.5)
plt.xlabel('Living area')
plt.ylabel('Sale Price')
plt.title('living area vs log sale price')
plt.show()

# %%
# QUALITY VS PRICE

house.boxplot(
    column = 'SalePrice',
    by = 'OverallQual',
    figsize = (8,5)
)

plt.title('sale price by over all quality')
suptitle = ""
plt.xlabel('over all quality')
plt.ylabel('sale price')
plt.show()

# %%
# USE BOOLEAN MASKING (NUMPY POWER)

house[house['GrLivArea'] > 4000][['GrLivArea', 'SalePrice']]

# from this you could see big living area does not necessary equate high sale price which is quite an anomaly
# Out:
# Empty DataFrame
# Columns: [GrLivArea, SalePrice]
# Index: []

# %%
# REMOVE ONLY CLEAR ANOMALIES

house = house[house['GrLivArea'] < 4000]

# %%
# plot after removing anomalies

plt.scatter(house['GrLivArea'], house['SalePrice'], alpha = 0.5)
plt.ylabel('Living Area')
plt.xlabel('Sale Price')
plt.title('living area vs price')
plt.show()

# %%
# WINSORIZATION

upper_cap = np.percentile(house['LotArea'], 95)

house = house.copy()
house['lotArea_wins'] = house['LotArea'].copy()

house.loc[house['lotArea_wins'] > upper_cap, 'lotArea_wins'] = upper_cap

# %%
# final EDA check

house.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# SaleType         0
# SaleCondition    0
# SalePrice        0
# SalePrice_log    0
# lotArea_wins     0
# Length: 78, dtype: int64

# %%
house.describe().head()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1456.000000  1456.000000  1456.000000   1456.000000  1456.000000
# mean    729.967033    56.888736    69.570055  10448.784341     6.088599
# std     421.722909    42.358363    20.903753   9860.763449     1.369669
# min       1.000000    20.000000    21.000000   1300.000000     1.000000
# 25%     364.750000    20.000000    60.000000   7538.750000     5.000000
#
#        OverallCond   YearBuilt  YearRemodAdd   BsmtFinSF1   BsmtFinSF2  \
# count  1456.000000  1456.00000   1456.000000  1456.000000  1456.000000
# mean      5.576236  1971.18544   1984.819368   436.991071    46.677198
# std       1.113966    30.20159     20.652143   430.255052   161.522376
# min       1.000000  1872.00000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.00000   1966.750000     0.000000     0.000000
#
#          BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF  \
# ...

# %%
house.shape
# Out:
# (1456, 78)

# %%
house.to_csv('clean_house_price.csv')
