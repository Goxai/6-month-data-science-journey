# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\data-science-journey\jupyter notebooks files\titanic dataset\train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
percentage_missing = df.isnull().sum() * 100 / len(df)
percentage_missing
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# What percentage of passengers survived?

surv_percen = df['Survived'].value_counts() * 100 / len(df['Survived'])
surv_percen
# from the code below, about 61.61% died and 38.38% survived
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: count, dtype: float64

# %%
surv_percen.reset_index()
# Out:
#    Survived      count
# 0         0  61.616162
# 1         1  38.383838

# %%
# visualise the percentage of passengers survived? 

plt.bar(surv_percen.index, surv_percen.values)
plt.xlabel('survived')
plt.title('percentage survival')
plt.show()

# %%
# What is the age distribution like?

plt.hist(df['Age'], bins = 20)
plt.xlabel('age')
plt.ylabel('frequency')
plt.title('age distribution')
plt.show()

# %%
# Did survival differ by gender?

df.groupby('Sex')['Survived'].value_counts().unstack()

# survival differs by gender, according to the data, famel has higher survival and lower death number than the male.
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
# Is fare skewed?

df['Fare'].mean()

# the mean is higher than the median, therefore fare is rightly skewed
# Out:
# np.float64(32.204207968574636)

# %%
df['Fare'].median()
# Out:
# 14.4542

# %%
# Which passenger class survived the most?

df.groupby('Pclass')['Survived'].value_counts().unstack()

# looking at the qnswer below, class 1 survived the most and also has lower deeath numbers
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
# Survival percentage for male vs female

df.groupby('Sex')['Survived'].mean()

#the female has a higher survival percentage rate of about 74.2% whille the male about 18.89%
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# Compute survival rate by class

df.groupby('Pclass')['Survived'].mean()
#the class 1 has the highest survival with 62.96 rate follow by class 2 with 47.28 rate and class 3  comes last with 24.23
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
# One numeric comparison

mean_fare = df['Fare'].mean()
mean_fare
# Out:
# np.float64(32.204207968574636)

# %%
fare_median = df['Fare'].median()
fare_median

# mean is 32.2 while the median is 14.45, since the mean is higher than the median, fare is skewed
# Out:
# 14.4542

# %%
plt.boxplot(df['Fare'], vert = False)
plt.xlabel('index')
plt.show()

# %%
# Create a new column with 'Is_Child → Age < 18'

df['Is_Child → Age < 18'] = df['Age'] < 18
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# the survival rate of 'Is_Child → Age < 18' 

df.groupby('Is_Child → Age < 18')['Survived'].mean()
# Out:
# Is_Child → Age < 18
# False    0.361183
# True     0.539823
# Name: Survived, dtype: float64

# %%
# aduklt survival rate

df.groupby(df['Age'] >= 18)['Survived'].mean()
# Out:
# Age
# False    0.389655
# True     0.381032
# Name: Survived, dtype: float64

# %%
# from the two code answer above, the 'Is_Child → Age < 18 has a higher survival rate of about 53.98% compared to the adult survival rate of 38.10%

#Who was most likely to survive on the Titanic and why?
# the children is most likely to survive the titanic because the adult will most likely want to
# protect the children and ensure more protect measures to make sure they are safe.

# %%
# add a new column is_child

df['is_child'] = df['Age'] < 18

# %%
df.drop(columns = 'Is_Child → Age < 18', axis = 1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# the survival rate of the child

df.groupby('is_child')['Survived'].mean()

# children has a survival rate of 53.98% compared to adult with 38.1% survival rate.
# Out:
# is_child
# False    0.361183
# True     0.539823
# Name: Survived, dtype: float64

# %%
#Who was most likely to survive and why?

# the children are mostly likely survive more because of the children and women first, will access to life jacket first and social norm
