# %% [raw]
# Working with files on python

# %%
file = open('note.txt', 'r')
content = file.read()
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 file = open('note.txt', 'r')
#       2 content = file.read()
#       3 file.close()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'note.txt'

# %%
with open('note.txt', 'r') as file
content = file.read()
print(content)

# %%
with open('note.txt', 'w') as file:
    file.write('hello! this is my first file')
print(file)
# Out:
# <_io.TextIOWrapper name='note.txt' mode='w' encoding='cp1252'>

# %%
with open('note.txt', 'a') as file:
    file.write('\nadd another line to thsi')
print(file)
# Out:
# <_io.TextIOWrapper name='note.txt' mode='a' encoding='cp1252'>

# %%
import csv

data = [
    ["name", "age", "score"],
    ["John", 18, 90],
    ["Amaka", 21, 78],
]



with open('students.csv', 'r', newline = '') as file:
    writer = csv.writer(file)
    writer.writerrow(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 13
#      11 with open('students.csv', 'r', newline = '') as file:
#      12     writer = csv.writer(file)
# ---> 13     writer.writerrow(data)
#
# AttributeError: '_csv.writer' object has no attribute 'writerrow'

# %%
import csv

with open("students.csv", "r") as file:
    reader = csv.DictReader(file)

    for row in reader:
        if int(row["score"]) > 80:
            print(row["name"])

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\user

# %%
import csv

data = [
    ["name", "age", "score"],
    ["John", 18, 90],
    ["Amaka", 21, 78],
    ["Leo", 19, 95]
]

with open("students.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerows(data)

# %% [markdown]
# myproject/
#     script.py
#     students.csv

# %%
import csv

with open('students.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age', 'score']
# ['John', '18', '90']
# ['Amaka', '21', '78']
# ['Leo', '19', '95']

# %%
with open('students.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        if int(row['score']) > 80:
            print(row['name'], row['score'])
# Out:
# John 90
# Leo 95

# %% [markdown]
# myproject/
#     script.py
#     house_listings.csv

# %%
import csv

with open('C:/Users/user/Documents/Data/Book_customers.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['ï»¿Customer ID', 'Customer Name', 'Age', 'Has School Aged Children', 'Has_Pets']
# ['101', 'Alexander', '36', 'Yes', 'No']
# ['102', 'Mason', '16', 'No', 'No']
# ['103', 'Ethan', '55', 'No', 'No']
# ['104', 'Daniel', '70', 'No', 'No']
# ['105', 'Michael', '18', 'No', 'Yes']
# ['106', 'Matthew', '40', 'Yes', 'No']
# ['107', 'Samuel', '49', 'Yes', 'No']
# ['108', 'Joseph', '42', 'Yes', 'No']
# ['109', 'Jackson', '64', 'No', 'No']
# ['110', 'David', '67', 'No', 'Yes']
# ['111', 'Carter', '17', 'No', 'No']
# ['112', 'Owen', '17', 'No', 'No']
# ['113', 'Sebastian', '53', 'No', 'No']
# ['114', 'Evelyn', '20', 'No', 'No']
# ['115', 'Abigail', '19', 'No', 'Yes']
# ['116', 'Emily', '51', 'No', 'No']
# ['117', 'Elizabeth', '37', 'No', 'No']
# ['118', 'Avery', '32', 'No', 'No']
# ['119', 'Ella', '48', 'No', 'No']
# ['120', 'Scarlett', '35', 'Yes', 'Yes']
# ['121', 'Chloe', '25', 'No', 'No']
# ['122', 'Victoria', '15', 'No', 'No']
# ['123', 'Madison', '28', 'Yes', 'No']
# ['124', 'Grace', '23', 'No', 'No']
# ['125', 'Hannah', '24', 'No', 'Yes']
# ['126', 'Wyatt', '68', 'No', 'No']
# ['127', 'Natalie', '21', 'No', 'No']
# ['128', 'Layla', '36', 'Yes', 'No']

# %%
with open('note.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# this is my first file creation prompt
#  introduce another line to the one before

# %%
import json

data = {
    "name": "John",
    "age": 22,
    "languages": ["Python", "SQL"]
}

with open('data.json', 'w') as file:
    json.dump(data, file, indent =4)

# %%
with open('data.json', 'r') as file:
    json.load(file)
    print(data)
    print(data['age'])
# Out:
# {'name': 'John', 'age': 22, 'languages': ['Python', 'SQL']}
# 22

# %%
import csv

data = [
    ["name", "age", "score"],
    ["John", 18, 90],
    ["Amaka", 21, 78],
    ["Leo", 19, 95]
]

with open('students.csv', 'w') as file:
    writer = csv.writer(file)
    writer.writerows(data)

# %%
with open('students.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age', 'score']
# []
# ['John', '18', '90']
# []
# ['Amaka', '21', '78']
# []
# ['Leo', '19', '95']
# []

# %%
import csv

students = []

with open('students.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        row['age'] = int(row['age'])
        row['score'] = int(row['score'])
        students.append(row)

# %%
#to get the highest score

top_student = max(students, key = lambda x : x['score'])
print(top_student)
# Out:
# {'name': 'Leo', 'age': 19, 'score': 95}

# %%
#save summary into json


import json

summary = {
    'top_student': top_student['name'],
    'top_score': top_student['score']
}

with open('summary.json', 'w') as file:
    json.dump(summary, file, indent = 4)

# %%
with open('summary.json', 'r') as file:
    data = json.load(file)

# %%
with open("log.txt", "a") as file:
    file.write(f"Processed {len(students)} students.\n")
    file.write(f"Top student: {top_student['name']} ({top_student['score']})\n")

# %%
with open('log.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Processed 3 students.
# Top student: Leo (95)
# Processed 3 students.
# Top student: Leo (95)

# %%
import csv


students = [
    ["Name", "Math", "English", "Science"],
    ["Alice", 85, 90, 88],
    ["Bob", 78, 82, 80],
    ["Carol", 92, 88, 95]
]
with open('students.csv', 'w', newline = '') as file:
    writer = csv.writer(file)
    writer.writerows(students)

# %%
import csv

with open('students.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Math', 'English', 'Science']
# ['Alice', '85', '90', '88']
# ['Bob', '78', '82', '80']
# ['Carol', '92', '88', '95']

# %%
with open('note.txt', 'w') as file:
    file.write('this is my first file creation prompt')

# %%
with open('note.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# this is my first file creation prompt

# %%
with open('note.txt', 'a') as file:
    file.write('\n introduce another line to the one before')

# %%
with open('note.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# this is my first file creation prompt
#  introduce another line to the one before

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\user

# %%
print(os.listdir())
# Out:
# ['.anaconda', '.conda', '.condarc', '.continuum', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.python_history', '.virtual_documents', '3D Objects', 'anaconda3', 'anaconda_projects', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'data.csv', 'data.json', 'data.txt', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'handling python files.ipynb', 'handling python files1.ipynb', 'house_listings.csv', 'IntelGraphicsProfiles', 'Links', 'Local Settings', 'log.txt', 'Music', 'My Documents', 'NetHood', 'new python folder', 'new python pract', 'note.txt', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{ac891fa2-6680-11f0-a9db-98e7f4e9e2b0}.TM.blf', 'NTUSER.DAT{ac891fa2-6680-11f0-a9db-98e7f4e9e2b0}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{ac891fa2-6680-11f0-a9db-98e7f4e9e2b0}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'practice project.py', 'practice1.ipynb', 'practice2.ipynb', 'practicepython.ipynb', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'students.csv', 'summary.json', 'Templates', 'tutorial.ipynb', 'unfinished project.ipynb', 'Untitled2.ipynb', 'Videos']

# %%
# create a text folder called data

with open('data.txt', 'w') as file:
    file.write('this is a new folder called data')

# %%
with open('data.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# this is a new folder called data

# %%
# create a csv file folder called data

import csv

data = [
    ["Name", "Math", "English"],
    ["Alice", 90, 85],
    ["Bob", 78, 92]
]

with open('data.csv', 'w', newline = '') as file:
    writer = csv.writer(file)
    writer.writerows(data)

# %%
import csv

with open('data.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Math', 'English']
# ['Alice', '90', '85']
# ['Bob', '78', '92']

# %%
import json

data = {
    "name": "Alice",
    "scores": [90, 85, 88]
}

with open('data.json', 'w') as file:
    json.dump(data, file, indent = 4)

# %%
with open('data.json', 'r') as file:
    gunlet = json.load(file)
    print(gunlet)
# Out:
# {'name': 'Alice', 'scores': [90, 85, 88]}

# %%
with open('C:/Users/user/Desktop/data/students.txt', 'w') as file:
    file.write('this is a new folder\n i am learning python file handling')

# %%
import csv

rows = [
    ["Name", "Math", "English"],
    ["Alice", 90, 85],
    ["Bob", 78, 92]
]

with open('C:/Users/user/Desktop/data/students.csv', 'w', newline = '') as file:
    writer = csv.writer(file)
    writer.writerows(rows)

# %%
import json

students = {
    "name": "Alice",
    "scores": [90, 85, 88]
}

with open('C:/Users/user/Desktop/data/students.json', 'w') as file:
    json.dump(students, file, indent = 4)

# %%
#read a text file


with open('C:/Users/user/Desktop/data/students.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# this is a new folder
#  i am learning python file handling

# %%
# read a csv file

with open('C:/Users/user/Desktop/data/students.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Math', 'English']
# ['Alice', '90', '85']
# ['Bob', '78', '92']

# %%
import json

# read a json file


with open('C:/Users/user/Desktop/data/students.json', 'r') as file:
    students = json.load(file)
    print(students)
# Out:
# {'name': 'Alice', 'scores': [90, 85, 88]}

# %%
import csv

# reading python files and doing some calculations
# find each students average 

with open('C:/Users/user/Desktop/data/students.csv', 'r') as file:
    reader = csv.DictReader(file)
    
    for row in reader:
        name = row['Name']
        math = int(row['Math'])
        eng = int(row['English'])

        avg_score = (math + eng) / 2
        print(name, 'average_score = ', avg_score)
# Out:
# Alice average_score =  87.5
# Bob average_score =  85.0

# %%
import csv

with open('C:/Users/user/Desktop/data/students.csv', "r") as f:
    reader = csv.DictReader(f)

    for row in reader:
        name = row["Name"]
        math = int(row["Math"])
        eng = int(row["English"])

        avg = (math + eng) / 2
        print(name, " average =", avg)
# Out:
# Alice  average = 87.5
# Bob  average = 85.0

# %%
import csv

#find the top student without pandas
top_name = ''
top_avg = 0

with open('C:/Users/user/Desktop/data/students.csv', 'r') as file:
    reader = csv.DictReader(file)
    
    for row in reader:
        math = int(row["Math"])
        eng = int(row["English"])
        
        avg = (math + eng) / 2
        
        if avg > top_avg:
            top_avg = avg
            top_name = row["Name"]
            
print('top studen:', top_name, 'with average:', top_avg)
# Out:
# top studen: Alice with average: 87.5

# %%
import csv

top_name = ""
top_avg = 0

with open('C:/Users/user/Desktop/data/students.csv', 'r') as f:
    reader = csv.DictReader(f)

    for row in reader:
        math = int(row["Math"])
        eng = int(row["English"])
        avg = (math + eng) / 2

        if avg > top_avg:
            top_avg = avg
            top_name = row["Name"]

print("Top student:", top_name, "with average of", top_avg)
# Out:
# Top student: Alice with average of 87.5

# %%
import csv

#find class statistics

scores = []
math_scores = []
eng_scores = []

with open('C:/Users/user/Desktop/data/students.csv', 'r') as file:
    reader = csv.DictReader(file)

    for row in reader:
        math = int(row['Math'])
        eng = int(row['English'])

        scores.extend([math, eng])
        math_scores.append(math)
        eng_scores.append(eng)

print('class average:', sum(scores) / len(scores)),
print('math average:', sum(math_scores) / len(math_scores)),
print('eng average:', sum(eng_scores) / len(eng_scores))
# Out:
# class average: 86.25
# math average: 84.0
# eng average: 88.5

# %% [markdown]
# more mini exercise on file handling

# %%
import csv

students = []

#read the available students csv file 

with open('C:/Users/user/Desktop/data/students.csv', 'r') as file:
    reader = csv.reader(file)
    next(reader)
    for row in reader:
        name = row[0]
        score1 = int(row[1])
        score2 = int(row[2])

         #calculate the average scores
        average = (score1 + score2) / 2

        #add reamrks
        
        remarks = 'Pass' if average >= 50 else 'fail'

        #update the row
        
        students.append((name, score1, score2, average, remarks))

#create a new =students file called staudents with remarks

with open('students_with_remarks.csv', 'w', newline = '') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'score1', 'score2', 'average', 'remarks'])
    writer.writerows(students)
print('new file created: students_with_remarks')
# Out:
# new file created: students_with_remarks

# %%
import shutil
shutil.copy("students_with_remarks_backup.csv", "students_with_remarks.csv")
# Out:
# 'students_with_remarks.csv'

# %%
#looking for a specific name on a file in python

import csv
def find_student(Name, filename = 'students_with_remarks_backup.csv'):
    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['Name'].strip().lower() == Name.strip().lower():
                return row
    return None

#using the function created above

student_file = find_student('Alice')
if student_file:
    print('found :', student_file)
else:
    print('student file not found')
# Out:
# student file not found

# %%
# adding student details to a file

import csv

def add_student(Name, score1, score2, filename = 'students_with_remarks_backup.csv'):
    average = (score1 + score2) / 2
    remarks = 'pass' if average >= 50 else 'fail'

    with open(filename, 'a', newline = '') as file:
        writer = csv.writer(file)
        writer.writerow([Name, score1, score2, average, remarks])
    print(f'added {Name} (avg ={average}), remarks = {remarks}. ')

# %%
add_student("Chris", 65, 72)
# Out:
# added Chris (avg =68.5), remarks = pass.

# %%
# revision of how to find specific info in a file

import csv

def find_students_info(Name, filename = 'students_with_remarks_backup.csv'):
    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['Name'].strip().lower() == Name.strip().lower():
                return row
                
    return None

student_info = find_students_info('Alice')
if student_info:
    print('found', student_info)
else:
    print('not found')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 14
#      10                 return row
#      12     return None
# ---> 14 student_info = find_students_info('Alice')
#      15 if student_info:
#      16     print('found', student_info)
#
# Cell In[103], line 9, in find_students_info(Name, filename)
#       7     reader = csv.DictReader(file)
#       8     for row in reader:
# ----> 9         if row['Name'].strip().lower() == Name.strip().lower():
#      10             return row
#      12 return None
#
# KeyError: 'Name'

# %%
# revision on how to add info to a file

import csv

def add_students_info(Name, score1, score2, filename = 'students_with_remarks.csv'):
    average = (score1 + score2) / 2
    remarks = 'Pass' if average >= 50 else 'Fail'

    with open(filename, 'a', newline = '') as file:
        writer = csv.writer(file)
        writer.writerow([Name, score1, score2, average, remarks])
        #writer = writerows(students)
    print(f'added {Name} (average = {average}, remarks = {remarks})')


#Example

new_students = add_students_info("Chris", 65, 72)
print(new_students)
# Out:
# added Chris (average = 68.5, remarks = Pass)
# None

# %%
# to avoid students being added multiple times

import csv

def add_onetime(Name, score1, score2, filename = 'students_with_remarks_backup.csv'):
    if find_students_info(Name, filename):
        print(f'{Name} already exists - add another')
        return f'{Name} already exists'

    result = add_student(Name, score1, score2, filename)
    return result

#example

new_takein = add_onetime("goxai", 65, 72)
print(new_takein)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 15
#      11     return result
#      13 #example
# ---> 15 new_takein = add_onetime("goxai", 65, 72)
#      16 print(new_takein)
#
# Cell In[106], line 6, in add_onetime(Name, score1, score2, filename)
#       5 def add_onetime(Name, score1, score2, filename = 'students_with_remarks_backup.csv'):
# ----> 6     if find_students_info(Name, filename):
#       7         print(f'{Name} already exists - add another')
#       8         return f'{Name} already exists'
#
# Cell In[103], line 9, in find_students_info(Name, filename)
#       7     reader = csv.DictReader(file)
#       8     for row in reader:
# ----> 9         if row['Name'].strip().lower() == Name.strip().lower():
#      10             return row
#      12 return None
#
# KeyError: 'Name'

# %%
another_student = add_onetime('gabriel', 70, 90)
print(another_student)
# Out:
# gabriel already exists - add another
# gabriel already exists

# %%
another_student = add_onetime("Chris", 65, 72)
print(another_student)
# Out:
# Chris already exists - add another
# Chris already exists

# %%
another_student = add_onetime("Chika", 65, 72)
print(another_student)
# Out:
# added Chika (avg =68.5), remarks = pass.
# None

# %%
#deleting names from a file in file handling

import csv



def delete_student(Name, filename = 'students_with_remarks_backup.csv'):
    rows = []
    found = False

    with open('students_with_remarks_backup.csv', 'r', newline = '') as file:
        reader = csv.DictReader(file)
        header = reader.fieldnames

        for row in reader:
            if row['Name'].strip().lower() == Name.strip().lower():
                found = True
                continue

            rows.append(row)

    if not found:
        return

    with open(filename, 'w', newline = '') as file:
        writer = csv.DictWriter(file, fieldnames = header)
        writer = writeheader()
        writer.writerows(rows)
        print(f'Deleted{Name} (if present).')
        return (f'Deleted{Name} (if present).')


#example
remove_student = delete_student('chris')
print(remove_student)
# Out:
# None

# %%
import csv
import json

def csv_to_json(csv_filename="students_with_remarks.csv", json_filename="students.json"):
    data = []
    with open(csv_filename, "r") as f:
        reader = csv.DictReader(f)
        for row in reader:
            # Convert numeric fields to numbers
            # Try converting Score1, Score2, Average if they exist
            for key in ("Score1","Score2","Average"):
                if key in row and row[key] != "":
                    try:
                        # Average may be float; scores usually int
                        if key == "Average":
                            row[key] = float(row[key])
                        else:
                            row[key] = int(row[key])
                    except ValueError:
                        pass
            data.append(row)
    with open(json_filename, "w") as jf:
        json.dump(data, jf, indent=4)
    print(f"Wrote {len(data)} records to {json_filename}")

# Example usage:
csv_to_json()
# Out:
# Wrote 6 records to students.json

# %%
add_onetime("Zara", 70, 80)
# Out:
# added Zara (avg =75.0), remarks = pass.
