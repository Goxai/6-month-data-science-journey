# %% [markdown]
# Continuation of pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('students_file.csv')
print(df)
# Out:
#     name  age  score
# 0  Alice   20     88
# 1    Bob   22     95
# 2   John   19     76
# 3   Mary   21     90

# %%
import shutil

shutil.copy('students_file.csv', 'students_file_copy.csv')
# Out:
# 'students_file_copy.csv'

# %%
df['status'] = ['pass' if score >= 90 else 'fail' for score in df['score']]
print(df)
# Out:
#     name  age  score status
# 0  Alice   20     88   fail
# 1    Bob   22     95   pass
# 2   John   19     76   fail
# 3   Mary   21     90   pass

# %%
df.name
# Out:
# 0    Alice
# 1      Bob
# 2     John
# 3     Mary
# Name: name, dtype: object

# %%
df.iloc[:2, 0]
# Out:
# 0    Alice
# 1      Bob
# Name: name, dtype: object

# %%
df.iloc[1:3, 0]
# Out:
# 1     Bob
# 2    John
# Name: name, dtype: object

# %%
df.iloc[[0, 1,2], 0]
# Out:
# 0    Alice
# 1      Bob
# 2     John
# Name: name, dtype: object

# %%
df.iloc[-3:]
# Out:
#    name  age  score status
# 1   Bob   22     95   pass
# 2  John   19     76   fail
# 3  Mary   21     90   pass

# %%
df.loc[0, 'name']
# Out:
# 'Alice'

# %%
# new dataset

df = pd.read_csv('C:/Users/user/Desktop/data-science-journey/Datasets/house_listings.csv')
print(df)
# Out:
#        SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0    MLS Listing        NaN                Condo/Co-op
# 1    MLS Listing        NaN  Single Family Residential
# 2    MLS Listing        NaN  Single Family Residential
# 3    MLS Listing        NaN                Condo/Co-op
# 4    MLS Listing        NaN  Single Family Residential
# ..           ...        ...                        ...
# 338  MLS Listing        NaN                Condo/Co-op
# 339  MLS Listing        NaN                Condo/Co-op
# 340  MLS Listing        NaN                    Parking
# 341  MLS Listing        NaN  Single Family Residential
# 342  MLS Listing        NaN                Condo/Co-op
#
#                            ADDRESS     CITY STATE OR PROVINCE  \
# 0         1335 S Prairie Ave #1105  Chicago                IL
# 1                 4944 W Roscoe St  Chicago                IL
# 2            8111 S Scottsdale Ave  Chicago                IL
# ...

# %%
df.iloc[:5, ]
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0  MLS Listing        NaN                Condo/Co-op
# 1  MLS Listing        NaN  Single Family Residential
# 2  MLS Listing        NaN  Single Family Residential
# 3  MLS Listing        NaN                Condo/Co-op
# 4  MLS Listing        NaN  Single Family Residential
#
#                     ADDRESS     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE  \
# 0  1335 S Prairie Ave #1105  Chicago                IL               60605
# 1          4944 W Roscoe St  Chicago                IL               60641
# 2     8111 S Scottsdale Ave  Chicago                IL               60652
# 3       4335 N Mozart St #1  Chicago                IL               60618
# 4        5736 S Loomis Blvd  Chicago                IL               60636
#
#     PRICE  BEDS  BATHS  ...  STATUS  NEXT OPEN HOUSE START TIME  \
# 0  799000   3.0    2.5  ...  Active                         NaN
# ...

# %%
df.loc[:, ['SALE TYPE', 'CITY', 'PROPERTY TYPE', 'STATUS', 'PRICE' ]]
# Out:
#        SALE TYPE     CITY              PROPERTY TYPE  STATUS   PRICE
# 0    MLS Listing  Chicago                Condo/Co-op  Active  799000
# 1    MLS Listing  Chicago  Single Family Residential  Active  424900
# 2    MLS Listing  Chicago  Single Family Residential  Active  265000
# 3    MLS Listing  Chicago                Condo/Co-op  Active  325000
# 4    MLS Listing  Chicago  Single Family Residential  Active  159900
# ..           ...      ...                        ...     ...     ...
# 338  MLS Listing  Chicago                Condo/Co-op  Active  649000
# 339  MLS Listing  Chicago                Condo/Co-op  Active  265000
# 340  MLS Listing  Chicago                    Parking  Active   72000
# 341  MLS Listing  Chicago  Single Family Residential  Active  245000
# 342  MLS Listing  Chicago                Condo/Co-op  Active  190000
#
# [343 rows x 5 columns]

# %%
df.iloc[[0,1,2,3,4,5], [2,3]]
# Out:
#                PROPERTY TYPE                    ADDRESS
# 0                Condo/Co-op   1335 S Prairie Ave #1105
# 1  Single Family Residential           4944 W Roscoe St
# 2  Single Family Residential      8111 S Scottsdale Ave
# 3                Condo/Co-op        4335 N Mozart St #1
# 4  Single Family Residential         5736 S Loomis Blvd
# 5  Single Family Residential  6619 S Saint Lawrence Ave

# %%
df.CITY == 'Chicago'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 338    True
# 339    True
# 340    True
# 341    True
# 342    True
# Name: CITY, Length: 343, dtype: bool

# %%
# conditional selection

df.loc[df.CITY == 'Chicago']
# Out:
#        SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0    MLS Listing        NaN                Condo/Co-op
# 1    MLS Listing        NaN  Single Family Residential
# 2    MLS Listing        NaN  Single Family Residential
# 3    MLS Listing        NaN                Condo/Co-op
# 4    MLS Listing        NaN  Single Family Residential
# ..           ...        ...                        ...
# 338  MLS Listing        NaN                Condo/Co-op
# 339  MLS Listing        NaN                Condo/Co-op
# 340  MLS Listing        NaN                    Parking
# 341  MLS Listing        NaN  Single Family Residential
# 342  MLS Listing        NaN                Condo/Co-op
#
#                            ADDRESS     CITY STATE OR PROVINCE  \
# 0         1335 S Prairie Ave #1105  Chicago                IL
# 1                 4944 W Roscoe St  Chicago                IL
# 2            8111 S Scottsdale Ave  Chicago                IL
# ...

# %%
df.loc[(df.CITY == 'Chicago') & (df.PRICE >= 100000)]
# Out:
#        SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0    MLS Listing        NaN                Condo/Co-op
# 1    MLS Listing        NaN  Single Family Residential
# 2    MLS Listing        NaN  Single Family Residential
# 3    MLS Listing        NaN                Condo/Co-op
# 4    MLS Listing        NaN  Single Family Residential
# ..           ...        ...                        ...
# 337  MLS Listing        NaN                Condo/Co-op
# 338  MLS Listing        NaN                Condo/Co-op
# 339  MLS Listing        NaN                Condo/Co-op
# 341  MLS Listing        NaN  Single Family Residential
# 342  MLS Listing        NaN                Condo/Co-op
#
#                          ADDRESS     CITY STATE OR PROVINCE  \
# 0       1335 S Prairie Ave #1105  Chicago                IL
# 1               4944 W Roscoe St  Chicago                IL
# 2          8111 S Scottsdale Ave  Chicago                IL
# ...

# %%
df.loc[(df.CITY == 'Chicago') | (df.PRICE >= 600000)]
# Out:
#        SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0    MLS Listing        NaN                Condo/Co-op
# 1    MLS Listing        NaN  Single Family Residential
# 2    MLS Listing        NaN  Single Family Residential
# 3    MLS Listing        NaN                Condo/Co-op
# 4    MLS Listing        NaN  Single Family Residential
# ..           ...        ...                        ...
# 338  MLS Listing        NaN                Condo/Co-op
# 339  MLS Listing        NaN                Condo/Co-op
# 340  MLS Listing        NaN                    Parking
# 341  MLS Listing        NaN  Single Family Residential
# 342  MLS Listing        NaN                Condo/Co-op
#
#                            ADDRESS     CITY STATE OR PROVINCE  \
# 0         1335 S Prairie Ave #1105  Chicago                IL
# 1                 4944 W Roscoe St  Chicago                IL
# 2            8111 S Scottsdale Ave  Chicago                IL
# ...

# %%
df.CITY
# Out:
# 0      Chicago
# 1      Chicago
# 2      Chicago
# 3      Chicago
# 4      Chicago
#         ...
# 338    Chicago
# 339    Chicago
# 340    Chicago
# 341    Chicago
# 342    Chicago
# Name: CITY, Length: 343, dtype: object

# %%
df.loc[df.CITY.isin(['Chicago'])]
# Out:
#        SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0    MLS Listing        NaN                Condo/Co-op
# 1    MLS Listing        NaN  Single Family Residential
# 2    MLS Listing        NaN  Single Family Residential
# 3    MLS Listing        NaN                Condo/Co-op
# 4    MLS Listing        NaN  Single Family Residential
# ..           ...        ...                        ...
# 338  MLS Listing        NaN                Condo/Co-op
# 339  MLS Listing        NaN                Condo/Co-op
# 340  MLS Listing        NaN                    Parking
# 341  MLS Listing        NaN  Single Family Residential
# 342  MLS Listing        NaN                Condo/Co-op
#
#                            ADDRESS     CITY STATE OR PROVINCE  \
# 0         1335 S Prairie Ave #1105  Chicago                IL
# 1                 4944 W Roscoe St  Chicago                IL
# 2            8111 S Scottsdale Ave  Chicago                IL
# ...

# %%
df.loc[df.CITY.notnull()]
# Out:
#        SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0    MLS Listing        NaN                Condo/Co-op
# 1    MLS Listing        NaN  Single Family Residential
# 2    MLS Listing        NaN  Single Family Residential
# 3    MLS Listing        NaN                Condo/Co-op
# 4    MLS Listing        NaN  Single Family Residential
# ..           ...        ...                        ...
# 338  MLS Listing        NaN                Condo/Co-op
# 339  MLS Listing        NaN                Condo/Co-op
# 340  MLS Listing        NaN                    Parking
# 341  MLS Listing        NaN  Single Family Residential
# 342  MLS Listing        NaN                Condo/Co-op
#
#                            ADDRESS     CITY STATE OR PROVINCE  \
# 0         1335 S Prairie Ave #1105  Chicago                IL
# 1                 4944 W Roscoe St  Chicago                IL
# 2            8111 S Scottsdale Ave  Chicago                IL
# ...

# %%
df.loc[df.CITY.isnull()]
# Out:
# Empty DataFrame
# Columns: [SALE TYPE, SOLD DATE, PROPERTY TYPE, ADDRESS, CITY, STATE OR PROVINCE, ZIP OR POSTAL CODE, PRICE, BEDS, BATHS, LOCATION, SQUARE FEET, LOT SIZE, YEAR BUILT, DAYS ON MARKET, $/SQUARE FEET, HOA/MONTH, STATUS, NEXT OPEN HOUSE START TIME, NEXT OPEN HOUSE END TIME, URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING), SOURCE, MLS#, FAVORITE, INTERESTED, LATITUDE, LONGITUDE]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# Summary functions

# %%
df.PRICE.describe()
# Out:
# count    3.430000e+02
# mean     4.665273e+05
# std      4.882045e+05
# min      2.000000e+04
# 25%      2.099000e+05
# 50%      3.250000e+05
# 75%      5.324500e+05
# max      3.995000e+06
# Name: PRICE, dtype: float64

# %%
df.CITY.describe()
# Out:
# count         343
# unique          1
# top       Chicago
# freq          343
# Name: CITY, dtype: object

# %%
df.PRICE.mean()
# Out:
# np.float64(466527.25947521866)

# %%
df.CITY.unique()
# Out:
# array(['Chicago'], dtype=object)

# %%
df.CITY.value_counts()
# Out:
# CITY
# Chicago    343
# Name: count, dtype: int64

# %% [markdown]
# Maps

# %%
df[df['PRICE'] >= 900000] ['CITY']
# Out:
# 6      Chicago
# 52     Chicago
# 80     Chicago
# 102    Chicago
# 103    Chicago
# 118    Chicago
# 130    Chicago
# 131    Chicago
# 147    Chicago
# 152    Chicago
# 166    Chicago
# 169    Chicago
# 171    Chicago
# 180    Chicago
# 189    Chicago
# 195    Chicago
# 205    Chicago
# 208    Chicago
# 216    Chicago
# 219    Chicago
# 234    Chicago
# 237    Chicago
# 247    Chicago
# 311    Chicago
# 312    Chicago
# 315    Chicago
# 327    Chicago
# 331    Chicago
# Name: CITY, dtype: object

# %%
df[df['PRICE'] >= 1000000]
# Out:
#        SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 6    MLS Listing        NaN                Condo/Co-op
# 52   MLS Listing        NaN  Single Family Residential
# 80   MLS Listing        NaN    Multi-Family (2-4 Unit)
# 102  MLS Listing        NaN    Multi-Family (2-4 Unit)
# 103  MLS Listing        NaN                Condo/Co-op
# 118  MLS Listing        NaN                Condo/Co-op
# 130  MLS Listing        NaN                Condo/Co-op
# 131  MLS Listing        NaN                Condo/Co-op
# 147  MLS Listing        NaN                Vacant Land
# 166  MLS Listing        NaN  Single Family Residential
# 169  MLS Listing        NaN                Condo/Co-op
# 171  MLS Listing        NaN  Single Family Residential
# 180  MLS Listing        NaN    Multi-Family (2-4 Unit)
# 189  MLS Listing        NaN                Vacant Land
# 205  MLS Listing        NaN                Condo/Co-op
# 208  MLS Listing        NaN                Condo/Co-op
# ...
